# %%
import royale.cards as cards
import royale.battlelog as bl
import json

# %%
bl.save_or_update_battlelog("#88V8GQU")
# Out:
# {'file': '/home/simonetto/project_royale/Royale_Predict/data/mine/#88V8GQU.json',
#  'previous': 67,
#  'fetched': 30,
#  'added': 2,
#  'total': 69}

# %%
import glob
import json

files = glob.glob("./data/all/*.json")
for f in files:
    tag=f[11:-5]  # solo il tag, senza path e .json
    stats = bl.save_or_update_battlelog(tag)
    print(stats)
# Out:
# {'file': '/home/simonetto/project_royale/Royale_Predict/data/all/#YPP0YLQ.json', 'previous': 74, 'fetched': 39, 'added': 20, 'total': 94}
# {'file': '/home/simonetto/project_royale/Royale_Predict/data/all/#L9L8P080.json', 'previous': 111, 'fetched': 40, 'added': 20, 'total': 131}
# {'file': '/home/simonetto/project_royale/Royale_Predict/data/all/#U2VVU0LJ2.json', 'previous': 75, 'fetched': 31, 'added': 9, 'total': 84}
# {'file': '/home/simonetto/project_royale/Royale_Predict/data/all/#J9UQQRL0G.json', 'previous': 56, 'fetched': 30, 'added': 4, 'total': 60}
# {'file': '/home/simonetto/project_royale/Royale_Predict/data/all/#V8YVY8UG2.json', 'previous': 12, 'fetched': 9, 'added': 9, 'total': 21}
# {'file': '/home/simonetto/project_royale/Royale_Predict/data/all/#202LYJYVJJ.json', 'previous': 10, 'fetched': 0, 'added': 0, 'total': 10}
# {'file': '/home/simonetto/project_royale/Royale_Predict/data/all/#2JQR8LR9Y.json', 'previous': 66, 'fetched': 40, 'added': 4, 'total': 70}
# {'file': '/home/simonetto/project_royale/Royale_Predict/data/all/#2QGG9GJ80.json', 'previous': 72, 'fetched': 34, 'added': 29, 'total': 101}
# {'file': '/home/simonetto/project_royale/Royale_Predict/data/all/#2QQRV0VQ.json', 'previous': 90, 'fetched': 30, 'added': 30, 'total': 120}
# {'file': '/home/simonetto/project_royale/Royale_Predict/data/all/#UQ9PG2VPG.json', 'previous': 50, 'fetched': 30, 'added': 5, 'total': 55}
# {'file': '/home/simonetto/project_royale/Royale_Predict/data/all/#QCC2GJ2GU.json', 'previous': 55, 'fetched': 30, 'added': 16, 'total': 71}
# {'file': '/home/simonetto/project_royale/Royale_Predict/data/all/#CCRQRJGYV.json', 'previous': 65, 'fetched': 30, 'added': 15, 'total': 80}
# {'file': '/home/simonetto/project_royale/Royale_Predict/data/all/#GJRVPLQGG.json', 'previous': 91, 'fetched': 30, 'added': 9, 'total': 100}
# {'file': '/home/simonetto/project_royale/Royale_Predict/data/all/#808QQ0QV2.json', 'previous': 152, 'fetched': 30, 'added': 16, 'total': 168}
# {'file': '/home/simonetto/project_royale/Royale_Predict/data/all/#RUGJCQL08.json', 'previous': 128, 'fetched': 40, 'added': 16, 'total': 144}
# {'file': '/home/simonetto/project_royale/Royale_Predict/data/all/#29QP2J88.json', 'previous': 88, 'fetched': 40, 'added': 8, 'total': 96}
# {'file': '/home/simonetto/project_royale/Royale_Predict/data/all/#GCPURVCR.json', 'previous': 100, 'fetched': 30, 'added': 17, 'total': 117}
# {'file': '/home/simonetto/project_royale/Royale_Predict/data/all/#CVCQG99VG.json', 'previous': 89, 'fetched': 30, 'added': 30, 'total': 119}
# {'file': '/home/simonetto/project_royale/Royale_Predict/data/all/#2002UCQURP.json', 'previous': 106, 'fetched': 30, 'added': 7, 'total': 113}
# {'file': '/home/simonetto/project_royale/Royale_Predict/data/all/#P9VVGJYLV.json', 'previous': 70, 'fetched': 39, 'added': 30, 'total': 100}
# {'file': '/home/simonetto/project_royale/Royale_Predict/data/all/#2GRC0YYJ.json', 'previous': 69, 'fetched': 38, 'added': 4, 'total': 73}
# {'file': '/home/simonetto/project_royale/Royale_Predict/data/all/#Y2C9YVRUJ.json', 'previous': 175, 'fetched': 40, 'added': 17, 'total': 192}
# {'file': '/home/simonetto/project_royale/Royale_Predict/data/all/#9L9VPJC9U.json', 'previous': 156, 'fetched': 35, 'added': 30, 'total': 186}
# {'file': '/home/simonetto/project_royale/Royale_Predict/data/all/#YYRCCPYLQ.json', 'previous': 149, 'fetched': 30, 'added': 25, 'total': 174}
# {'file': '/home/simonetto/project_royale/Royale_Predict/data/all/#RP9R9JRG.json', 'previous': 150, 'fetched': 30, 'added': 22, 'total': 172}
# {'file': '/home/simonetto/project_royale/Royale_Predict/data/all/#JR90UCU2P.json', 'previous': 67, 'fetched': 40, 'added': 0, 'total': 67}
# {'file': '/home/simonetto/project_royale/Royale_Predict/data/all/#VJU2GLQ28.json', 'previous': 20, 'fetched': 1, 'added': 1, 'total': 21}
# {'file': '/home/simonetto/project_royale/Royale_Predict/data/all/#YQCPY09UJ.json', 'previous': 98, 'fetched': 34, 'added': 0, 'total': 98}
# {'file': '/home/simonetto/project_royale/Royale_Predict/data/all/#V2VLCGQP8.json', 'previous': 28, 'fetched': 5, 'added': 5, 'total': 33}
# {'file': '/home/simonetto/project_royale/Royale_Predict/data/all/#JVUV8PJGC.json', 'previous': 94, 'fetched': 30, 'added': 4, 'total': 98}
# {'file': '/home/simonetto/project_royale/Royale_Predict/data/all/#JL2G9P8.json', 'previous': 52, 'fetched': 30, 'added': 2, 'total': 54}

# %%
# cards.show_match_decks(bl.get_battlelog("#88V8GQU")[0])
cards.show_match_decks(bl.load_battlelog_from_file("./data/mine/#88V8GQU.json")[0])
# Out:
# Risultato: FIERO! #88V8GQU  3 - 0  XDasta #V9RPCYGQJ

# %%
cards.show_cards(['26000002'], show_evo=True)
