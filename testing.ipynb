# %%
import royale.cards as cards
import royale.battlelog as bl

# %%
bl.save_or_update_battlelog("#88V8GQU")
# Out:
# {'file': '/home/simonetto/royale/Royale_Predict/data/mine/#88V8GQU.json',
#  'previous': 45,
#  'fetched': 30,
#  'added': 0,
#  'total': 45}

# %%
print(len(bl.load_battlelog_from_file('./data/all/#2GRC0YYJ.json')))
# Out:
# 43

# %%
cards.show_cards(['26000103'])

# cards.show_match_decks(bl.get_battlelog("#88V8GQU")[0])
cards.show_match_decks(bl.load_battlelog_from_file("./data/mine/#88V8GQU.json")[0])
# Out:
# Risultato: FIERO! #88V8GQU  0 - 1  <c6>Jornite3 #20VYPRL9Q
